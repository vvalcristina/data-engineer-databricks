# %% [markdown]
# d-sandbox
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 400px">
# </div>

# %% [markdown]
# # Complex Types
#
# ##### Methods
# - DataFrame (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=dataframe#pyspark.sql.DataFrame" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/Dataset.html" target="_blank">Scala</a>): `union`
# - Built-In Functions (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=functions#module-pyspark.sql.functions" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/functions$.html" target="_blank">Scala</a>):
#   - Collection: `explode`, `array_contains`, `element_at`, `collect_set`
#   - String: `split`

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) User Purchases
# List all size and quality options purchased by each buyer.
# 1. Extract item details from purchases
# 2. Extract size and quality options from mattress purchases
# 3. Extract size and quality options from pillow purchases
# 4. Combine data for mattress and pillows
# 5. List all size and quality options bought by each user

# %%
# %run ./Includes/Classroom-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets mounted and student environment set up

# %%
df = spark.read.parquet(salesPath)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>email</th><th>transaction_timestamp</th><th>total_item_quantity</th><th>purchase_revenue_in_usd</th><th>unique_items</th><th>items</th></tr></thead><tbody><tr><td>257437</td><td>kmunoz@powell-duran.com</td><td>1592194221828900</td><td>1</td><td>1995.0</td><td>1</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td></tr><tr><td>282611</td><td>bmurillo@hotmail.com</td><td>1592504237604072</td><td>1</td><td>940.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td></tr><tr><td>257448</td><td>bradley74@gmail.com</td><td>1592200438030141</td><td>1</td><td>945.0</td><td>1</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td></tr><tr><td>257440</td><td>jameshardin@campbell-morris.biz</td><td>1592197217716495</td><td>1</td><td>1045.0</td><td>1</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td></tr><tr><td>283949</td><td>whardin@hotmail.com</td><td>1592510720760323</td><td>1</td><td>535.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td></tr><tr><td>257444</td><td>emily88@cobb.com</td><td>1592199040703476</td><td>1</td><td>1045.0</td><td>1</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td></tr><tr><td>257449</td><td>craig61@luna-oliver.com</td><td>1592200459769596</td><td>1</td><td>1195.0</td><td>1</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>257441</td><td>johnsonashley@mcclain.com</td><td>1592197729873798</td><td>1</td><td>945.0</td><td>1</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td></tr><tr><td>264191</td><td>maxwelltara@edwards.com</td><td>1592306255847870</td><td>2</td><td>993.6</td><td>2</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1), List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1))</td></tr><tr><td>286727</td><td>rojasjorge@yahoo.com</td><td>1592533048926949</td><td>1</td><td>535.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td></tr><tr><td>287573</td><td>marmstrong46@hotmail.com</td><td>1592547727220317</td><td>1</td><td>53.1</td><td>1</td><td>List(List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1))</td></tr><tr><td>257462</td><td>ndavis79@yahoo.com</td><td>1592204258037615</td><td>1</td><td>595.0</td><td>1</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td></tr><tr><td>257458</td><td>xadams@salazar.com</td><td>1592203707959868</td><td>1</td><td>1095.0</td><td>1</td><td>List(List(null, M_PREM_T, Premium Twin Mattress, 1095.0, 1095.0, 1))</td></tr><tr><td>257464</td><td>chadjones@williams.com</td><td>1592204292754623</td><td>2</td><td>2390.0</td><td>2</td><td>List(List(null, M_PREM_Q, Premium Queen Mattress, 1795.0, 1795.0, 1), List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td></tr><tr><td>271597</td><td>johnsonderrick@yahoo.com</td><td>1592399808941985</td><td>5</td><td>2846.7</td><td>5</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1), List(NEWBED10, P_DOWN_K, King Down Pillow, 143.1, 159.0, 1), List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1), List(NEWBED10, M_PREM_T, Premium Twin Mattress, 985.5, 1095.0, 1), List(NEWBED10, P_DOWN_S, Standard Down Pillow, 107.10000000000001, 119.0, 1))</td></tr><tr><td>257500</td><td>chavezbenjamin@byrd.com</td><td>1592208672234813</td><td>1</td><td>1045.0</td><td>1</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td></tr><tr><td>278696</td><td>ericzimmerman@valentine.com</td><td>1592477039776439</td><td>1</td><td>850.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1))</td></tr><tr><td>284289</td><td>gtra ...

# %% [markdown]
# ### 1. Extract item details from purchases
# - Explode **`items`** field in **`df`**
# - Select **`email`** and **`item.item_name`** fields
# - Split words in **`item_name`** into an array and alias with "details"
#
# Assign the resulting DataFrame to **`detailsDF`**.

# %%
from pyspark.sql.functions import *

detailsDF = (df.withColumn("items", explode("items"))
  .select("email", "items.item_name")
  .withColumn("details", split(col("item_name"), " "))             
)
display(detailsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>item_name</th><th>details</th></tr></thead><tbody><tr><td>kmunoz@powell-duran.com</td><td>Premium King Mattress</td><td>List(Premium, King, Mattress)</td></tr><tr><td>bmurillo@hotmail.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>bradley74@gmail.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td></tr><tr><td>jameshardin@campbell-morris.biz</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>whardin@hotmail.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>emily88@cobb.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>craig61@luna-oliver.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>johnsonashley@mcclain.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td></tr><tr><td>maxwelltara@edwards.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>maxwelltara@edwards.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td></tr><tr><td>rojasjorge@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>marmstrong46@hotmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td></tr><tr><td>ndavis79@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>xadams@salazar.com</td><td>Premium Twin Mattress</td><td>List(Premium, Twin, Mattress)</td></tr><tr><td>chadjones@williams.com</td><td>Premium Queen Mattress</td><td>List(Premium, Queen, Mattress)</td></tr><tr><td>chadjones@williams.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>King Down Pillow</td><td>List(King, Down, Pillow)</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Premium Twin Mattress</td><td>List(Premium, Twin, Mattress)</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Standard Down Pillow</td><td>List(Standard, Down, Pillow)</td></tr><tr><td>chavezbenjamin@byrd.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>ericzimmerman@valentine.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td></tr><tr><td>gtravis@sosa.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>austin10@robinson-burton.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>wilsonteresa@walsh.net</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>hilljoshua43@hotmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td></tr><tr><td>gcummings@mullins-smith.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>ashleylevy@gonzalez.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>jwilson@gmail.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td></tr><tr><td>gayala@phillips.net</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td></tr><tr><td>john1545@hotmail.com</td><td>Premium Twin Mattress</td><td>List(Premium, Twin, Mattress)</td></tr><tr><td>annagray@kaufman.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td></tr><tr><td>doylechristina@lopez.info</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td></tr><tr><td>doylechristina@lopez.info</td><td>Standard Twin Mattress</td><td>List(Standard, Twin ...

# %% [markdown]
# ### 2. Extract size and quality options from mattress purchases
# - Filter **`detailsDF`** for records where **`details`** contains "Mattress"
# - Add **`size`** column from extracting element at position 2
# - Add **`quality`** column from extracting element at position 1
#
# Save result as **`mattressDF`**.

# %%
mattressDF = (detailsDF.filter(array_contains(col("details"), "Mattress"))
  .withColumn("size", element_at(col("details"), 2))
  .withColumn("quality", element_at(col("details"), 1))
)           
display(mattressDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>item_name</th><th>details</th><th>size</th><th>quality</th></tr></thead><tbody><tr><td>kmunoz@powell-duran.com</td><td>Premium King Mattress</td><td>List(Premium, King, Mattress)</td><td>King</td><td>Premium</td></tr><tr><td>bmurillo@hotmail.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td><td>Standard</td></tr><tr><td>bradley74@gmail.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td><td>Full</td><td>Standard</td></tr><tr><td>jameshardin@campbell-morris.biz</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td><td>Standard</td></tr><tr><td>whardin@hotmail.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td><td>Standard</td></tr><tr><td>emily88@cobb.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td><td>Standard</td></tr><tr><td>craig61@luna-oliver.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td><td>Standard</td></tr><tr><td>johnsonashley@mcclain.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td><td>Full</td><td>Standard</td></tr><tr><td>maxwelltara@edwards.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td><td>Standard</td></tr><tr><td>rojasjorge@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td><td>Standard</td></tr><tr><td>ndavis79@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td><td>Standard</td></tr><tr><td>xadams@salazar.com</td><td>Premium Twin Mattress</td><td>List(Premium, Twin, Mattress)</td><td>Twin</td><td>Premium</td></tr><tr><td>chadjones@williams.com</td><td>Premium Queen Mattress</td><td>List(Premium, Queen, Mattress)</td><td>Queen</td><td>Premium</td></tr><tr><td>chadjones@williams.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td><td>Standard</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td><td>Standard</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td><td>Standard</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Premium Twin Mattress</td><td>List(Premium, Twin, Mattress)</td><td>Twin</td><td>Premium</td></tr><tr><td>chavezbenjamin@byrd.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td><td>Standard</td></tr><tr><td>ericzimmerman@valentine.com</td><td>Standard Full Mattress</td><td>List(Standard, Full, Mattress)</td><td>Full</td><td>Standard</td></tr><tr><td>gtravis@sosa.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td><td>Standard</td></tr><tr><td>austin10@robinson-burton.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td><td>Standard</td></tr><tr><td>wilsonteresa@walsh.net</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td><td>Standard</td></tr><tr><td>gcummings@mullins-smith.com</td><td>Standard Queen Mattress</td><td>List(Standard, Queen, Mattress)</td><td>Queen</td><td>Standard</td></tr><tr><td>ashleylevy@gonzalez.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td><td>Standard</td></tr><tr><td>jwilson@gmail.com</td><td>Standard King Mattress</td><td>List(Standard, King, Mattress)</td><td>King</td><td>Standard</td></tr><tr><td>john1545@hotmail.com</td><td>Premium Twin Mattress</td><td>List(Premium, Twin, Mattress)</td><td>Twin</td><td>Premium</td></tr><tr><td>annagray@kaufman.com</td><td>Standard Twin Mattress</td><td>List(Standard, Twin, Mattress)</td><td>Twin</td><td>Standard</td></tr ...

# %% [markdown]
# ### 3. Extract size and quality options from pillow purchases
# - Filter **`detailsDF`** for records where **`details`** contains "Pillow"
# - Add **`size`** column from extracting element at position 1
# - Add **`quality`** column from extracting element at position 2
#
# Note the positions of **`size`** and **`quality`** are switched for mattresses and pillows.
#
# Save result as **`pillowDF`**.

# %%
pillowDF = (detailsDF.filter(array_contains(col("details"), "Pillow"))
  .withColumn("size", element_at(col("details"), 1))
  .withColumn("quality", element_at(col("details"), 2))
)           
display(pillowDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>item_name</th><th>details</th><th>size</th><th>quality</th></tr></thead><tbody><tr><td>maxwelltara@edwards.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>marmstrong46@hotmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>King Down Pillow</td><td>List(King, Down, Pillow)</td><td>King</td><td>Down</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Standard Down Pillow</td><td>List(Standard, Down, Pillow)</td><td>Standard</td><td>Down</td></tr><tr><td>hilljoshua43@hotmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>gayala@phillips.net</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>andrew5297@hotmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>owerner@yahoo.com</td><td>Standard Down Pillow</td><td>List(Standard, Down, Pillow)</td><td>Standard</td><td>Down</td></tr><tr><td>racheljackson@gmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>dstout@keith.net</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>christopher69@gutierrez-flores.info</td><td>Standard Down Pillow</td><td>List(Standard, Down, Pillow)</td><td>Standard</td><td>Down</td></tr><tr><td>aprillee@mendez.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>palmerjonathan@washington.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>glopez@figueroa.net</td><td>King Down Pillow</td><td>List(King, Down, Pillow)</td><td>King</td><td>Down</td></tr><tr><td>troyturner@gmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>boothashley@hotmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>vjohnson@montgomery-wilson.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>osanchez28@yahoo.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>egarner@wallace.com</td><td>Standard Down Pillow</td><td>List(Standard, Down, Pillow)</td><td>Standard</td><td>Down</td></tr><tr><td>maria28@yahoo.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>uguerrero@hotmail.com</td><td>Standard Down Pillow</td><td>List(Standard, Down, Pillow)</td><td>Standard</td><td>Down</td></tr><tr><td>kingrebecca@camacho.com</td><td>King Down Pillow</td><td>List(King, Down, Pillow)</td><td>King</td><td>Down</td></tr><tr><td>chloerivera@davis.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>morrismary@gmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>boydkimberly56@yahoo.com</td><td>King Foam Pillow</td><td>List(King, Foam, Pillow)</td><td>King</td><td>Foam</td></tr><tr><td>sarah43@gmail.com</td><td>King Foam Pillow</td><td>List(King, Foam, Pillow)</td><td>King</td><td>Foam</td></tr><tr><td>prestonnelson@gmail.com</td><td>Standard Foam Pillow</td><td>List(Standard, Foam, Pillow)</td><td>Standard</td><td>Foam</td></tr><tr><td>kaylabuchanan@yahoo.com</td><td>King Foam Pillow</td><td>List(King, Foam, Pillow)</td><td>King</td><td>Foam</td></tr><tr><td>carl93@hill.com</td><td>Standard Down Pil ...

# %% [markdown]
# ### 4. Combine data for mattress and pillows
# - Perform a union on **`mattressDF`** and **`pillowDF`** by column names
# - Drop **`details`** column
#
# Save result as **`unionDF`**.

# %%
unionDF = (mattressDF.unionByName(pillowDF)
  .drop("details"))
display(unionDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>item_name</th><th>size</th><th>quality</th></tr></thead><tbody><tr><td>kmunoz@powell-duran.com</td><td>Premium King Mattress</td><td>King</td><td>Premium</td></tr><tr><td>bmurillo@hotmail.com</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>bradley74@gmail.com</td><td>Standard Full Mattress</td><td>Full</td><td>Standard</td></tr><tr><td>jameshardin@campbell-morris.biz</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>whardin@hotmail.com</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>emily88@cobb.com</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>craig61@luna-oliver.com</td><td>Standard King Mattress</td><td>King</td><td>Standard</td></tr><tr><td>johnsonashley@mcclain.com</td><td>Standard Full Mattress</td><td>Full</td><td>Standard</td></tr><tr><td>maxwelltara@edwards.com</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>rojasjorge@yahoo.com</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>ndavis79@yahoo.com</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>xadams@salazar.com</td><td>Premium Twin Mattress</td><td>Twin</td><td>Premium</td></tr><tr><td>chadjones@williams.com</td><td>Premium Queen Mattress</td><td>Queen</td><td>Premium</td></tr><tr><td>chadjones@williams.com</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Standard King Mattress</td><td>King</td><td>Standard</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>johnsonderrick@yahoo.com</td><td>Premium Twin Mattress</td><td>Twin</td><td>Premium</td></tr><tr><td>chavezbenjamin@byrd.com</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>ericzimmerman@valentine.com</td><td>Standard Full Mattress</td><td>Full</td><td>Standard</td></tr><tr><td>gtravis@sosa.com</td><td>Standard King Mattress</td><td>King</td><td>Standard</td></tr><tr><td>austin10@robinson-burton.com</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>wilsonteresa@walsh.net</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>gcummings@mullins-smith.com</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>ashleylevy@gonzalez.com</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>jwilson@gmail.com</td><td>Standard King Mattress</td><td>King</td><td>Standard</td></tr><tr><td>john1545@hotmail.com</td><td>Premium Twin Mattress</td><td>Twin</td><td>Premium</td></tr><tr><td>annagray@kaufman.com</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>doylechristina@lopez.info</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>doylechristina@lopez.info</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>amy7022@gmail.com</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>darren48@lucas-hayes.net</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>kbennett@gmail.com</td><td>Premium Twin Mattress</td><td>Twin</td><td>Premium</td></tr><tr><td>tammyroth@gmail.com</td><td>Standard King Mattress</td><td>King</td><td>Standard</td></tr><tr><td>bennettzachary88@gmail.com</td><td>Standard Queen Mattress</td><td>Queen</td><td>Standard</td></tr><tr><td>barryandrew@roy-gonzalez.com</td><td>Premium King Mattress</td><td>King</td><td>Premium</td></tr><tr><td>brittany447@yahoo.com</td><td>Standard Twin Mattress</td><td>Twin</td><td>Standard</td></tr><tr><td>marieperez@yahoo.com</td><td>Premium Full Mattress</td><td>Full</td><td>Premium</td></tr><tr><td>awilson@gmail.com</td><td>Standard Twin Mattress ...

# %% [markdown]
# ### 5. List all size and quality options bought by each user
# - Group rows in **`unionDF`** by **`email`**
#   - Collect set of all items in **`size`** for each user with alias "size options"
#   - Collect set of all items in **`quality`** for each user with alias "quality options"
#
# Save result as **`optionsDF`**.

# %%
optionsDF = (unionDF.groupBy("email")
  .agg(collect_set("size").alias("size options"),
       collect_set("quality").alias("quality options"))
)
display(optionsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>size options</th><th>quality options</th></tr></thead><tbody><tr><td>aadkins@hill.biz</td><td>List(Twin)</td><td>List(Standard)</td></tr><tr><td>aalexander@hotmail.com</td><td>List(King)</td><td>List(Standard)</td></tr><tr><td>aallen43@hotmail.com</td><td>List(Queen, Twin)</td><td>List(Premium, Standard)</td></tr><tr><td>aallen@keith-taylor.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aalvarez4@gmail.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aalvarez@gmail.com</td><td>List(Queen, Full)</td><td>List(Standard)</td></tr><tr><td>aanderson26@hotmail.com</td><td>List(Queen)</td><td>List(Premium)</td></tr><tr><td>aaron01@hotmail.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aaron04@wolfe.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aaron05@hotmail.com</td><td>List(Twin)</td><td>List(Premium)</td></tr><tr><td>aaron11@mcdonald.com</td><td>List(Full)</td><td>List(Premium)</td></tr><tr><td>aaron12@yahoo.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aaron15@daniels.org</td><td>List(Full)</td><td>List(Standard)</td></tr><tr><td>aaron2097@hotmail.com</td><td>List(Twin)</td><td>List(Standard)</td></tr><tr><td>aaron46@gmail.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aaron48@gmail.com</td><td>List(Full)</td><td>List(Standard)</td></tr><tr><td>aaron57@mcconnell-holder.com</td><td>List(Twin)</td><td>List(Premium)</td></tr><tr><td>aaron58@gmail.com</td><td>List(Standard)</td><td>List(Down)</td></tr><tr><td>aaron58@hayden.net</td><td>List(Full)</td><td>List(Standard)</td></tr><tr><td>aaron6364@hotmail.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aaron6511@gmail.com</td><td>List(Twin)</td><td>List(Standard)</td></tr><tr><td>aaron74@golden.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aaron74@hotmail.com</td><td>List(King)</td><td>List(Standard)</td></tr><tr><td>aaron77@clayton.com</td><td>List(Queen, Twin)</td><td>List(Standard)</td></tr><tr><td>aaron78@gmail.com</td><td>List(King)</td><td>List(Standard)</td></tr><tr><td>aaron82@garcia-wilson.info</td><td>List(Twin)</td><td>List(Premium)</td></tr><tr><td>aaron8445@hotmail.com</td><td>List(Twin)</td><td>List(Standard)</td></tr><tr><td>aaron86@day.com</td><td>List(Twin)</td><td>List(Standard)</td></tr><tr><td>aaron87@cobb-smith.com</td><td>List(King, Standard)</td><td>List(Standard, Down)</td></tr><tr><td>aaron89@yahoo.com</td><td>List(Standard)</td><td>List(Foam)</td></tr><tr><td>aaron940@yahoo.com</td><td>List(Twin)</td><td>List(Premium)</td></tr><tr><td>aaron951@gmail.com</td><td>List(Queen)</td><td>List(Premium, Standard)</td></tr><tr><td>aaron96@simpson.org</td><td>List(King)</td><td>List(Standard)</td></tr><tr><td>aaron97@hotmail.com</td><td>List(Standard)</td><td>List(Down)</td></tr><tr><td>aaronaustin@gmail.com</td><td>List(Twin)</td><td>List(Standard)</td></tr><tr><td>aaronbarnett@gmail.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aaroncalhoun@howell-hill.com</td><td>List(Twin)</td><td>List(Premium)</td></tr><tr><td>aaroncarney@brewer-alexander.org</td><td>List(King)</td><td>List(Standard)</td></tr><tr><td>aaronclark@guzman.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aaroncrawford@castillo-zimmerman.net</td><td>List(Full)</td><td>List(Standard)</td></tr><tr><td>aaronday2@yahoo.com</td><td>List(Standard)</td><td>List(Down)</td></tr><tr><td>aarondrake@ray.com</td><td>List(Queen)</td><td>List(Standard)</td></tr><tr><td>aarongarcia@gmail.com</td><td>List(Twin)</td><td>List(Standard)</td></tr><tr><td>aarongarcia@jones-washington.info</td><td>List(Full)</td><td>List(Standard)</td></tr><tr><td>aarongreene@parrish.com</td><td>List(Queen, King)</td><td>List(Standard)</td></tr><tr><td>aarongriffin@frank.info</td><td>List(Full, Standard)</td><td>List(Standard, Foam)</td></tr><tr><td ...

# %% [markdown]
# ### Clean up classroom

# %%
# %run ./Includes/Classroom-Cleanup
# Out:
# Dropped database and removed files in working directory

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
